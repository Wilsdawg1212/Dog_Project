# %% [markdown]
# # Dog Breed Classifier CNN

# %%
from datasets import load_dataset
from src.data import create_dataloaders
from datasets import load_dataset
from src.data import create_dataloaders
from src.model import build_model, get_normalization
from src.train import main

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Load the data!

# %%
dataset = load_dataset("amaye15/stanford-dogs")
num_classes = dataset["train"].features["label"].num_classes

loaders = create_dataloaders(dataset, batch_size=64, img_size=224)

train_loader = loaders["train"]
val_loader   = loaders["val"]

# %% [markdown]
# Build the model!

# %%
model_type = "resnet"
model = build_model(model_type, num_classes=num_classes)

# %% [markdown]
# Train the Model!

# %%
main(
    dataset=dataset,
    model=model,
    model_type=model_type
)

# %% [markdown]
# Save the model!

# %%
torch.save(model.state_dict(), "/content/drive/MyDrive/Colab_Notebooks/models/dog_model_resnet.pt")
